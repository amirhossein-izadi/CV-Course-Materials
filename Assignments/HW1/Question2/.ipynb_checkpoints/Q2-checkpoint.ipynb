# %%
import cv2 as cv
from PIL import Image
import matplotlib.pyplot as plt 
import numpy as np
import re

# %%
def read_image_data(file_path):
    with open(file_path) as file:
        lines = file.readlines()

    height, width, expected_stars = map(int, lines[0].split(' '))
    pixel_data = lines[1:]
    return height, width, expected_stars, pixel_data

# %%
def parse_pixels(pixels):
    pattern = re.compile(r'\((\d+), (\d+), (\d+)\)')
    matches = pattern.findall(pixels)
    return [(int(r), int(g), int(b)) for r, g, b in matches]

# %%
def load_image(height, width, pixel_data):
    flat_image = [pixel for pixels in pixel_data for pixel in parse_pixels(pixels)]
    return np.array(flat_image, dtype=np.uint8).reshape(height, width, 3)

# %%
def preprocess_image(image):
    # Convert the image to grayscale
    gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
    
    # Apply Gaussian blur
    blurred_image = cv.GaussianBlur(gray_image, (5, 5), 0)
    
    return blurred_image

# %%
def find_contours(image):
    # Experiment with different threshold values
    _, thresh = cv.threshold(image, 190, 255, cv.THRESH_BINARY)
    
    contours, _ = cv.findContours(thresh, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
    return contours

# %%
def draw_contours(image, contours):
    result_img = image.copy()
    for contour in contours:
        x, y, w, h = cv.boundingRect(contour)
        center_x, center_y = x + w/2, y + h/2
        print(f'X = {center_x}, Y = {center_y}')
        result_img = cv.rectangle(result_img, (x, y), (x+w, y+h), (255, 0, 0), 1)
    return result_img

# %%
image_path = "input3.txt"
height, width, expected_stars, pixel_data = read_image_data(image_path)
original_image = load_image(height, width, pixel_data)

# %%
plt.imshow(original_image, cmap=plt.cm.gray)
plt.title("Original Image")
plt.show()

# %%
# Set this flag based on your criteria for noise
preprocess_flag = True

if preprocess_flag:
    # Preprocess the image
    preprocessed_image = preprocess_image(original_image)

    plt.imshow(preprocessed_image, cmap=plt.cm.gray)
    plt.title("Preprocessed Image")
    plt.show()

    contours = find_contours(preprocessed_image)
else:
    contours = find_contours(original_image)

# %%
# Set this flag based on your criteria for noise
preprocess_flag = False

if preprocess_flag:
    # Preprocess the image
    preprocessed_image = preprocess_image(original_image)

    plt.imshow(preprocessed_image, cmap=plt.cm.gray)
    plt.title("Preprocessed Image")
    plt.show()

    contours = find_contours(preprocessed_image)
else:
    gray_original_image = cv.cvtColor(original_image, cv.COLOR_BGR2GRAY)
    contours = find_contours(gray_original_image)

# %%
print(f'Number of Expected Stars: {expected_stars}')
print(f'Number of Detected Stars: {len(contours)}')
# Out:
# Number of Expected Stars: 26
# Number of Detected Stars: 108

# %%
print("Central points of each founded star:")
result_image_with_contours = draw_contours(original_image, contours)
# Out:
# Central points of each founded star:
# X = 317.5, Y = 269.5
# X = 60.5, Y = 263.5
# X = 338.5, Y = 254.5
# X = 121.5, Y = 254.5
# X = 330.5, Y = 253.5
# X = 170.5, Y = 253.0
# X = 78.5, Y = 252.5
# X = 140.0, Y = 248.5
# X = 72.5, Y = 244.5
# X = 93.5, Y = 243.5
# X = 330.0, Y = 239.5
# X = 109.5, Y = 237.0
# X = 348.0, Y = 235.5
# X = 212.5, Y = 235.5
# X = 45.0, Y = 234.5
# X = 269.5, Y = 229.5
# X = 320.5, Y = 226.0
# X = 163.5, Y = 223.5
# X = 76.5, Y = 223.5
# X = 165.5, Y = 222.5
# X = 209.5, Y = 221.5
# X = 29.5, Y = 215.5
# X = 175.5, Y = 211.5
# X = 152.0, Y = 211.0
# X = 335.0, Y = 209.5
# X = 11.5, Y = 196.0
# X = 328.5, Y = 190.5
# X = 134.5, Y = 187.5
# X = 77.5, Y = 184.5
# X = 118.5, Y = 183.5
# X = 277.5, Y = 180.5
# X = 248.5, Y = 180.5
# X = 14.0, Y = 181.0
# X = 251.5, Y = 178.5
# X = 253.5, Y = 174.0
# X = 242.0, Y = 171.5
# X = 213.0, Y = 171.0
# X = 36.0, Y = 169.5
# X = 323.5, Y = 167.5
# X = 164.5, Y = 166.5
# X = 239.5, Y = 165.5
# X = 137.5, Y = 165.5
# X = 154.5, Y = 164.0
# X = 164.5, Y = 162.5
# X = 250.5, Y = 161.5
# X = 349.5, Y = 157.5
# X = 302.0, Y = 154.0
# X = 240.5, Y = 152.5
# X = 255.0, Y = 151.5
# X = 144.5, Y = 144.5
# X = 351.5, Y = 143.5
# X = 282.0, Y = 140.5
# X = 210.0, Y = 138.5
# X = 76.5, Y = 136.5
# X = 300.5, Y = 132.0
# X = 88.5, Y = 130.5
# X = 158.5, Y = 110.5
# X = 152.5, Y = 110.5
# X = 148.5, Y = 110.5
# X = 148.0, Y = 108.0
# X = 133.5, Y = 106.5
# X = 91.5, Y = 105.5
# X = 340.0, Y = 103.5
# X = 103.5, Y = 103.5
# X = 196.5, Y = 103.0
# X = 315.5, Y = 93.5
# X = 122.5, Y = 92.5
# X = 283.5, Y = 92.0
# X = 291.5, Y = 91.5
# X = 199.5, Y = 90.5
# X = 162.5, Y = 90.5
# X = 284.5, Y = 88.5
# X = 76.5, Y = 88.5
# X = 185.5, Y = 87.5
# X = 175.5, Y = 84.5
# X = 282.5, Y = 81.0
# X = 83.0, Y = 78.0
# X = 300.5, Y = 75.5
# X = 80.5, Y = 75.5
# X = 349.5, Y = 71.5
# X = 104.5, Y = 65.0
# X = 43.5, Y = 65.0
# X = 185.0, Y = 58.0
# X = 137.5, Y = 57.5
# X = 99.0, Y = 56.0
# X = 30.5, Y = 55.5
# X = 27.0, Y = 55.5
# X = 224.5, Y = 46.5
# X = 90.5, Y = 46.5
# X = 76.5, Y = 46.5
# X = 209.5, Y = 39.5
# X = 38.5, Y = 37.0
# X = 336.5, Y = 32.5
# X = 205.5, Y = 31.5
# X = 135.5, Y = 31.5
# X = 123.5, Y = 31.5
# X = 77.5, Y = 30.5
# X = 241.5, Y = 29.5
# X = 62.5, Y = 29.5
# X = 16.0, Y = 20.5
# X = 173.5, Y = 17.5
# X = 89.0, Y = 18.0
# X = 149.5, Y = 17.0
# X = 101.5, Y = 17.0
# X = 113.0, Y = 14.0
# X = 59.5, Y = 13.5
# X = 225.0, Y = 11.5
# X = 161.5, Y = 11.5

# %%
plt.imshow(result_image_with_contours)
plt.title("Stars with Central Points")
plt.show()

# %%
# Out:
# Number of Expected Stars: 3
# Number of Detected Stars: 742
# Central points of each founded star:
# X = 95.5, Y = 323.5
# X = 68.0, Y = 323.5
# X = 50.5, Y = 323.0
# X = 136.5, Y = 321.5
# X = 120.5, Y = 322.5
# X = 111.5, Y = 321.5
# X = 23.5, Y = 321.5
# X = 40.5, Y = 322.0
# X = 103.0, Y = 319.5
# X = 35.5, Y = 321.5
# X = 88.5, Y = 318.5
# X = 124.5, Y = 318.0
# X = 2.5, Y = 319.0
# X = 63.0, Y = 317.5
# X = 21.5, Y = 315.5
# X = 103.0, Y = 315.0
# X = 40.0, Y = 315.0
# X = 112.5, Y = 313.5
# X = 73.5, Y = 315.0
# X = 35.0, Y = 314.0
# X = 54.5, Y = 313.0
# X = 165.0, Y = 311.0
# X = 66.5, Y = 310.5
# X = 14.0, Y = 312.5
# X = 230.5, Y = 309.5
# X = 145.5, Y = 309.5
# X = 113.5, Y = 309.5
# X = 75.0, Y = 310.5
# X = 7.0, Y = 310.0
# X = 94.5, Y = 308.5
# X = 55.5, Y = 308.5
# X = 22.5, Y = 310.0
# X = 84.0, Y = 309.5
# X = 27.0, Y = 307.0
# X = 2.5, Y = 308.5
# X = 243.0, Y = 305.0
# X = 64.5, Y = 304.5
# X = 34.0, Y = 306.0
# X = 198.5, Y = 303.5
# X = 125.0, Y = 302.5
# X = 30.5, Y = 303.5
# X = 17.5, Y = 302.5
# X = 205.5, Y = 302.0
# X = 54.0, Y = 303.5
# X = 217.5, Y = 300.0
# X = 86.5, Y = 302.0
# X = 69.5, Y = 299.5
# X = 0.5, Y = 301.0
# X = 117.5, Y = 300.0
# X = 129.0, Y = 298.5
# X = 49.5, Y = 298.0
# X = 26.5, Y = 298.5
# X = 97.5, Y = 296.0
# X = 74.5, Y = 296.5
# X = 32.5, Y = 296.5
# X = 21.0, Y = 299.5
# X = 12.5, Y = 298.0
# X = 225.5, Y = 298.0
# X = 107.5, Y = 295.0
# X = 57.0, Y = 295.0
# X = 181.5, Y = 293.5
# X = 40.5, Y = 300.0
# X = 93.0, Y = 293.5
# X = 25.0, Y = 292.5
# X = 136.0, Y = 292.0
# X = 98.5, Y = 290.5
# X = 56.5, Y = 291.0
# X = 18.0, Y = 291.0
# X = 164.5, Y = 291.0
# X = 75.5, Y = 290.5
# X = 154.5, Y = 288.5
# X = 114.5, Y = 289.5
# X = 63.5, Y = 291.0
# X = 33.0, Y = 290.5
# X = 28.0, Y = 289.5
# X = 6.5, Y = 292.0
# X = 146.0, Y = 288.5
# X = 84.5, Y = 288.0
# X = 97.5, Y = 286.5
# X = 89.0, Y = 285.5
# X = 125.5, Y = 285.0
# X = 68.5, Y = 289.0
# X = 59.5, Y = 284.0
# X = 38.0, Y = 286.0
# X = 31.5, Y = 283.5
# X = 48.5, Y = 288.5
# X = 243.5, Y = 107.0
# X = 222.5, Y = 104.5
# X = 215.5, Y = 105.0
# X = 172.5, Y = 104.5
# X = 86.0, Y = 107.5
# X = 72.0, Y = 107.0
# X = 187.5, Y = 103.5
# X = 178.0, Y = 104.0
# X = 67.5, Y = 104.0
# X = 21.5, Y = 102.5
# X = 243.0, Y = 102.5
# X = 97.0, Y = 104.0
# X = 212.0, Y = 100.5
# X = 231.5, Y = 100.0
# X = 180.5, Y = 99.5
# X = 221.5, Y = 97.5
# X = 187.5, Y = 98.0
# X = 168.0, Y = 98.0
# X = 160.5, Y = 102.5
# X = 127.5, Y = 99.5
# X = 208.5, Y = 98.5
# X = 142.0, Y = 100.0
# X = 94.5, Y = 99.5
# X = 52.5, Y = 96.5
# X = 175.0, Y = 97.5
# X = 151.5, Y = 98.5
# X = 194.0, Y = 95.5
# X = 132.5, Y = 95.0
# X = 85.5, Y = 94.5
# X = 163.5, Y = 94.5
# X = 221.5, Y = 92.5
# X = 218.5, Y = 93.5
# X = 183.5, Y = 94.0
# X = 153.0, Y = 93.5
# X = 65.0, Y = 93.0
# X = 124.5, Y = 92.0
# X = 162.5, Y = 90.0
# X = 134.5, Y = 90.5
# X = 198.5, Y = 89.5
# X = 139.0, Y = 89.5
# X = 243.0, Y = 88.5
# X = 137.5, Y = 86.5
# X = 105.5, Y = 86.5
# X = 181.0, Y = 89.5
# X = 169.5, Y = 89.5
# X = 131.0, Y = 85.5
# X = 113.5, Y = 86.0
# X = 92.0, Y = 86.5
# X = 71.5, Y = 87.0
# X = 193.5, Y = 85.0
# X = 69.0, Y = 85.0
# X = 31.5, Y = 84.0
# X = 144.0, Y = 84.5
# X = 121.5, Y = 86.0
# X = 82.5, Y = 87.0
# X = 77.5, Y = 84.0
# X = 171.5, Y = 82.5
# X = 92.0, Y = 82.5
# X = 68.5, Y = 81.5
# X = 64.5, Y = 82.0
# X = 212.0, Y = 82.0
# X = 201.5, Y = 84.0
# X = 50.5, Y = 80.5
# X = 238.5, Y = 80.5
# X = 204.0, Y = 80.0
# X = 185.5, Y = 79.5
# X = 82.5, Y = 80.0
# X = 163.5, Y = 79.0
# X = 156.5, Y = 82.5
# X = 150.5, Y = 80.5
# X = 73.5, Y = 79.0
# X = 225.5, Y = 78.0
# X = 178.0, Y = 78.0
# X = 138.0, Y = 78.5
# X = 129.5, Y = 81.0
# X = 99.0, Y = 78.0
# X = 227.5, Y = 75.5
# X = 202.5, Y = 76.0
# X = 221.5, Y = 74.5
# X = 155.0, Y = 75.5
# X = 194.0, Y = 74.5
# X = 180.5, Y = 74.0
# X = 82.5, Y = 74.5
# X = 164.5, Y = 72.5
# X = 104.5, Y = 77.5
# X = 70.5, Y = 73.5
# X = 145.0, Y = 72.5
# X = 225.0, Y = 71.5
# X = 184.0, Y = 70.5
# X = 175.0, Y = 71.0
# X = 150.0, Y = 71.0
# X = 92.5, Y = 75.0
# X = 65.5, Y = 72.5
# X = 169.0, Y = 70.0
# X = 123.5, Y = 75.0
# X = 218.5, Y = 69.5
# X = 188.0, Y = 69.5
# X = 93.0, Y = 69.0
# X = 150.5, Y = 67.0
# X = 183.5, Y = 65.5
# X = 138.5, Y = 68.5
# X = 202.0, Y = 64.5
# X = 191.5, Y = 65.0
# X = 173.5, Y = 64.5
# X = 157.5, Y = 64.5
# X = 130.5, Y = 65.5
# X = 162.0, Y = 64.5
# X = 60.0, Y = 64.5
# X = 225.5, Y = 62.5
# X = 94.5, Y = 62.0
# X = 74.0, Y = 64.0
# X = 180.0, Y = 61.0
# X = 139.5, Y = 61.0
# X = 54.5, Y = 61.0
# X = 28.5, Y = 60.5
# X = 243.5, Y = 59.5
# X = 146.0, Y = 60.5
# X = 195.0, Y = 59.5
# X = 110.0, Y = 57.5
# X = 237.5, Y = 56.5
# X = 222.0, Y = 59.0
# X = 172.5, Y = 57.0
# X = 160.5, Y = 57.5
# X = 69.5, Y = 59.5
# X = 39.0, Y = 56.0
# X = 105.0, Y = 54.0
# X = 60.5, Y = 55.0
# X = 229.5, Y = 53.0
# X = 166.0, Y = 52.5
# X = 132.5, Y = 55.0
# X = 188.0, Y = 52.5
# X = 148.0, Y = 54.0
# X = 142.0, Y = 52.5
# X = 87.5, Y = 58.0
# X = 127.0, Y = 52.5
# X = 102.5, Y = 51.0
# X = 67.5, Y = 51.0
# X = 225.0, Y = 49.5
# X = 181.0, Y = 50.0
# X = 78.0, Y = 54.0
# X = 74.0, Y = 49.5
# X = 27.0, Y = 50.5
# X = 211.0, Y = 48.5
# X = 157.5, Y = 52.0
# X = 206.0, Y = 48.5
# X = 84.5, Y = 48.5
# X = 49.5, Y = 46.5
# X = 199.0, Y = 46.0
# X = 188.5, Y = 45.5
# X = 170.5, Y = 46.0
# X = 155.0, Y = 46.5
# X = 150.5, Y = 45.5
# X = 108.0, Y = 46.5
# X = 54.5, Y = 47.5
# X = 43.5, Y = 46.5
# X = 26.0, Y = 44.5
# X = 160.0, Y = 44.5
# X = 147.0, Y = 43.0
# X = 72.5, Y = 44.0
# X = 170.5, Y = 42.5
# X = 138.5, Y = 42.0
# X = 58.0, Y = 43.0
# X = 220.5, Y = 43.5
# X = 184.5, Y = 41.0
# X = 143.5, Y = 45.5
# X = 83.5, Y = 40.5
# X = 152.0, Y = 41.0
# X = 64.5, Y = 40.0
# X = 14.5, Y = 40.0
# X = 236.0, Y = 38.5
# X = 98.0, Y = 39.0
# X = 72.5, Y = 38.5
# X = 39.0, Y = 40.5
# X = 240.5, Y = 38.5
# X = 233.5, Y = 37.5
# X = 123.5, Y = 38.5
# X = 70.5, Y = 37.5
# X = 215.0, Y = 37.0
# X = 163.5, Y = 37.0
# X = 178.0, Y = 35.0
# X = 13.5, Y = 34.5
# X = 241.0, Y = 34.0
# X = 161.5, Y = 34.0
# X = 53.5, Y = 35.0
# X = 221.5, Y = 33.5
# X = 135.5, Y = 33.0
# X = 114.5, Y = 33.0
# X = 92.0, Y = 47.5
# X = 72.5, Y = 32.5
# X = 213.0, Y = 32.0
# X = 147.0, Y = 35.5
# X = 41.0, Y = 34.5
# X = 187.0, Y = 29.5
# X = 235.5, Y = 31.5
# X = 221.5, Y = 28.5
# X = 156.0, Y = 33.0
# X = 162.5, Y = 28.5
# X = 65.5, Y = 30.5
# X = 57.0, Y = 30.0
# X = 52.5, Y = 27.5
# X = 34.5, Y = 26.5
# X = 171.0, Y = 26.5
# X = 127.0, Y = 27.0
# X = 164.5, Y = 25.0
# X = 145.5, Y = 26.0
# X = 32.5, Y = 24.5
# X = 15.5, Y = 26.0
# X = 90.0, Y = 25.5
# X = 70.0, Y = 24.5
# X = 62.5, Y = 23.5
# X = 40.5, Y = 24.0
# X = 22.0, Y = 24.0
# X = 221.0, Y = 24.0
# X = 159.5, Y = 24.0
# X = 113.0, Y = 24.5
# X = 41.5, Y = 22.5
# X = 194.5, Y = 22.5
# X = 95.5, Y = 21.5
# X = 50.0, Y = 22.0
# X = 153.5, Y = 24.5
# X = 132.0, Y = 21.0
# X = 58.5, Y = 21.5
# X = 28.0, Y = 23.0
# X = 122.5, Y = 19.5
# X = 89.0, Y = 20.5
# X = 243.0, Y = 19.0
# X = 104.5, Y = 21.0
# X = 35.5, Y = 19.5
# X = 236.0, Y = 18.0
# X = 224.5, Y = 17.5
# X = 168.5, Y = 20.0
# X = 184.0, Y = 17.0
# X = 158.5, Y = 16.5
# X = 67.5, Y = 19.5
# X = 29.5, Y = 16.5
# X = 210.0, Y = 16.0
# X = 78.0, Y = 17.0
# X = 1.5, Y = 15.5
# X = 214.0, Y = 14.5
# X = 243.0, Y = 14.0
# X = 234.0, Y = 14.0
# X = 125.0, Y = 24.5
# X = 106.0, Y = 14.0
# X = 67.0, Y = 13.5
# X = 60.0, Y = 14.0
# X = 155.5, Y = 13.0
# X = 89.0, Y = 12.5
# X = 165.5, Y = 12.0
# X = 147.0, Y = 15.0
# X = 71.0, Y = 13.0
# X = 242.5, Y = 11.0
# X = 185.5, Y = 10.5
# X = 43.5, Y = 10.5
# X = 237.5, Y = 10.5
# X = 208.0, Y = 10.5
# X = 117.5, Y = 10.5
# X = 60.0, Y = 9.5
# X = 143.5, Y = 8.5
# X = 135.5, Y = 8.5
# X = 130.0, Y = 7.5
# X = 78.0, Y = 10.0
# X = 24.5, Y = 6.5
# X = 222.5, Y = 8.5
# X = 211.0, Y = 6.0
# X = 243.5, Y = 5.0
# X = 198.0, Y = 9.0
# X = 141.0, Y = 5.5
# X = 82.5, Y = 6.0
# X = 66.0, Y = 4.5
# X = 50.0, Y = 6.5
# X = 121.5, Y = 3.5
# X = 163.0, Y = 6.5
# X = 126.5, Y = 2.5
# X = 107.0, Y = 4.0
# X = 57.0, Y = 5.5
# X = 206.5, Y = 0.5
# X = 188.0, Y = 3.0
# X = 158.5, Y = 1.5
# X = 144.0, Y = 1.0
# X = 135.5, Y = 2.5
# X = 72.5, Y = 144.0
